# %%
import pandas as pd

data  = pd.read_csv('F:\VKV\pvary_fvary\pvary_fvary.csv')
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\V'
# <>:3: SyntaxWarning: invalid escape sequence '\V'
# C:\Users\student\AppData\Local\Temp\ipykernel_20808\3013094562.py:3: SyntaxWarning: invalid escape sequence '\V'
#   data  = pd.read_csv('F:\VKV\pvary_fvary\pvary_fvary.csv')

# %%
data['Powers'].unique()
# Out:
# array([-24, -22, -20, -18, -16, -14, -12, -10,  -8,  -6,  -4,  -2,   0,
#          2,   4,   6,   8,  10,  12,  14,  16], dtype=int64)

# %%
data  = pd.read_csv('pvary_fvary_cleaned.csv')

# %%
data['Powers'].unique()
